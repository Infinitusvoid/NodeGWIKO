# %%
from pathlib import Path

import gwiko
import gwiko_generate

gwiko.reload_lib("gwiko")
gwiko.reload_lib("gwiko_generate")




class Write():
    def __init__(self):
        self.tokens = []
    def add(self, el):
        self.tokens.append(el)
    def get_str(self):
        output = []

        for token in self.tokens:
            if isinstance(token, str):
                output.append(token)
        return "".join(output)

w = Write()

class int_type():
    def __init__(self, name):
        self.name = name
        self.value = 0
    def __str__(self):
        return "int " + self.name + " = " + str(self.value) + ";\n"
        
class vec3_type():
    def __init__(self, name):
        self.name = name
        self.x = 0.0
        self.y = 0.0
        self.z = 0.0
    def __str__(self):
        return "vec3 " + self.name + " = vec3(" + str(self.x) +", " + str(self.y) + ", " + str(self.z) + ");"

class Pallete_type():
    def __init__(self, name):
        self.name = name
        self.a = vec3_type(name + "_a")
        self.b = vec3_type(name + "_b")
        self.c = vec3_type(name + "_c")
        self.d = vec3_type(name + "_d")
        

class Parameters():
    def __init__(self):
        pass

def generate_source(w, frame):
    w.add("#define USE_FUNCTION option_"+str(4)+"\n");

    w.add("int int_frame = " +  str(frame) + ";\n")


    w.add("const vec3 pallete_0_a = vec3(0.5, 0.5, 0.5);");
    w.add("const vec3 pallete_0_b = vec3(0.5, 0.5, 0.5);");
    w.add("const vec3 pallete_0_c = vec3(1.0, 1.0, 1.0);");
    w.add("const vec3 pallete_0_d = vec3(0.00, 0.10, 0.20);");

    w.add("const vec3 pallete_1_a = vec3(0.5, 0.5, 0.5);");
    w.add("const vec3 pallete_1_b = vec3(0.5, 0.5, 0.5);");
    w.add("const vec3 pallete_1_c = vec3(1.0, 1.0, 1.0);");
    w.add("const vec3 pallete_1_d = vec3(0.00, 0.10, 0.20);");


    w.add("const vec2 texture_0_s0 = vec2(0.1, 0.1);");
    w.add("const vec2 texture_1_s0 = vec2(0.1, 0.1);");

    w.add("const float f_texture_0_t_f_multiplication_value = 1.0;");
    w.add("const float f_texture_1_t_f_multiplication_value = 1.0;");
    w.add("const float f_texture_2x_t_f_multiplication_value = 0.42;");

    w.add("const float f_texture_2x_frequency_0 = 100.0;");
    w.add("const float f_texture_2x_f0_amplitude = 1.0;");

    w.add("const float f_texture_2_mixture_2_to_1 = 0.5;");


    w.add("const float f_texture_2_mixture_r_u_0_factor = 0.1;");
    w.add("const float f_texture_2_mixture_r_v_0_factor = 0.1;");

    w.add("const float f_texture_2_mixture_g_u_0_factor = 0.1;");
    w.add("const float f_texture_2_mixture_g_v_0_factor = 0.1;");

    w.add("const float f_texture_2_mixture_b_u_0_factor = 0.1;");
    w.add("const float f_texture_2_mixture_b_v_0_factor = 0.1;");

    #// red
    w.add("const float fru_offset = 1.0;");
    w.add("const float fru_mult = 1.0;");

    w.add("const float fru_amp_0 = 1.0;");
    w.add("const float fru_freq_0 = 0.2;");
    w.add("const float fru_amp_1 = 1.0;");
    w.add("const float fru_freq_1 = 0.2;");
    w.add("const float fru_amp_2 = 1.0;");
    w.add("const float fru_freq_2 = 0.2;");
    w.add("const float fru_amp_3 = 1.0;");
    w.add("const float fru_freq_3 = 0.2;");
    w.add("const float fru_amp_4 = 1.0;");
    w.add("const float fru_freq_4 = 0.2;");
    w.add("const float fru_amp_5 = 1.0;");
    w.add("const float fru_freq_5 = 0.2;");
    w.add("const float fru_amp_6 = 1.0;");
    w.add("const float fru_freq_6 = 0.2;");
    w.add("const float fru_amp_7 = 1.0;");
    w.add("const float fru_freq_7 = 0.2;");

    w.add("const float frv_offset = 1.0;");
    w.add("const float frv_mult = 1.0;");

    w.add("const float frv_amp_0 = 1.0;");
    w.add("const float frv_freq_0 = 0.2;");
    w.add("const float frv_amp_1 = 1.0;");
    w.add("const float frv_freq_1 = 0.2;");
    w.add("const float frv_amp_2 = 1.0;");
    w.add("const float frv_freq_2 = 0.2;");
    w.add("const float frv_amp_3 = 1.0;");
    w.add("const float frv_freq_3 = 0.2;");
    w.add("const float frv_amp_4 = 1.0;");
    w.add("const float frv_freq_4 = 0.2;");
    w.add("const float frv_amp_5 = 1.0;");
    w.add("const float frv_freq_5 = 0.2;");
    w.add("const float frv_amp_6 = 1.0;");
    w.add("const float frv_freq_6 = 0.2;");
    w.add("const float frv_amp_7 = 1.0;");
    w.add("const float frv_freq_7 = 0.2;");
    
    #// green
    w.add("const float fgu_offset = 1.0;");
    w.add("const float fgu_mult = 1.0;");
    
    w.add("const float fgu_amp_0 = 1.0;");
    w.add("const float fgu_freq_0 = 0.2;");
    w.add("const float fgu_amp_1 = 1.0;");
    w.add("const float fgu_freq_1 = 0.2;");
    w.add("const float fgu_amp_2 = 1.0;");
    w.add("const float fgu_freq_2 = 0.2;");
    w.add("const float fgu_amp_3 = 1.0;");
    w.add("const float fgu_freq_3 = 0.2;");
    w.add("const float fgu_amp_4 = 1.0;");
    w.add("const float fgu_freq_4 = 0.2;");
    w.add("const float fgu_amp_5 = 1.0;");
    w.add("const float fgu_freq_5 = 0.2;");
    w.add("const float fgu_amp_6 = 1.0;");
    w.add("const float fgu_freq_6 = 0.2;");
    w.add("const float fgu_amp_7 = 1.0;");
    w.add("const float fgu_freq_7 = 0.2;");
    
    
    w.add("const float fgv_offset = 1.0;");
    w.add("const float fgv_mult = 1.0;");
    
    w.add("const float fgv_amp_0 = 1.0;");
    w.add("const float fgv_freq_0 = 0.2;");
    w.add("const float fgv_amp_1 = 1.0;");
    w.add("const float fgv_freq_1 = 0.2;");
    w.add("const float fgv_amp_2 = 1.0;");
    w.add("const float fgv_freq_2 = 0.2;");
    w.add("const float fgv_amp_3 = 1.0;");
    w.add("const float fgv_freq_3 = 0.2;");
    w.add("const float fgv_amp_4 = 1.0;");
    w.add("const float fgv_freq_4 = 0.2;");
    w.add("const float fgv_amp_5 = 1.0;");
    w.add("const float fgv_freq_5 = 0.2;");
    w.add("const float fgv_amp_6 = 1.0;");
    w.add("const float fgv_freq_6 = 0.2;");
    w.add("const float fgv_amp_7 = 1.0;");
    w.add("const float fgv_freq_7 = 0.2;");
    
    #// blue
    w.add("const float fbu_offset = 1.0;");
    w.add("const float fbu_mult = 1.0;");
    
    
    w.add("const float fbu_amp_0 = 1.0;");
    w.add("const float fbu_freq_0 = 0.2;");
    w.add("const float fbu_amp_1 = 1.0;");
    w.add("const float fbu_freq_1 = 0.2;");
    w.add("const float fbu_amp_2 = 1.0;");
    w.add("const float fbu_freq_2 = 0.2;");
    w.add("const float fbu_amp_3 = 1.0;");
    w.add("const float fbu_freq_3 = 0.2;");
    w.add("const float fbu_amp_4 = 1.0;");
    w.add("const float fbu_freq_4 = 0.2;");
    w.add("const float fbu_amp_5 = 1.0;");
    w.add("const float fbu_freq_5 = 0.2;");
    w.add("const float fbu_amp_6 = 1.0;");
    w.add("const float fbu_freq_6 = 0.2;");
    w.add("const float fbu_amp_7 = 1.0;");
    w.add("const float fbu_freq_7 = 0.2;");
    
    w.add("const float fbv_offset = 1.0;");
    w.add("const float fbv_mult = 1.0;");
    
    w.add("const float fbv_amp_0 = 1.0;");
    w.add("const float fbv_freq_0 = 0.2;");
    w.add("const float fbv_amp_1 = 1.0;");
    w.add("const float fbv_freq_1 = 0.2;");
    w.add("const float fbv_amp_2 = 1.0;");
    w.add("const float fbv_freq_2 = 0.2;");
    w.add("const float fbv_amp_3 = 1.0;");
    w.add("const float fbv_freq_3 = 0.2;");
    w.add("const float fbv_amp_4 = 1.0;");
    w.add("const float fbv_freq_4 = 0.2;");
    w.add("const float fbv_amp_5 = 1.0;");
    w.add("const float fbv_freq_5 = 0.2;");
    w.add("const float fbv_amp_6 = 1.0;");
    w.add("const float fbv_freq_6 = 0.2;");
    w.add("const float fbv_amp_7 = 1.0;");
    w.add("const float fbv_freq_7 = 0.2;");
    
    
    w.add("const float option_2_parameter_0 = 1.0;");
    w.add("const float option_2_parameter_1 = 1.0;");
    w.add("const float option_2_parameter_2 = 1.0;");
    w.add("const float option_2_parameter_3 = 1.0;");
    
    w.add("const float option_4_paramter_0 = 1.0;");
    w.add("const float option_4_paramter_1 = 1.0;");
    w.add("const float option_4_paramter_2 = 1.0;");
    w.add("const float option_4_paramter_3 = 1.0;");
    w.add("const float option_4_paramter_4 = 1.0;");
    
    
    w.add("float option_5_paramter_0 = 1.0;");
    w.add("float option_5_paramter_1 = 1.0;");
    
    w.add("const float option_7_paramter_0 = 1.0;");
    w.add("const float option_7_paramter_1 = 1.0;");
    
    w.add("const float parameter_time_varying_pixel_color = 1.0;");
    w.add("const float parameter_add_a_moving_gradient_based_on_time = 1.0;");
    w.add("const float parameter_apply_post_processing_effects = 1.0;");
    
    w.add("float parameter_t_offset = 1.0;");
    w.add("float parameter_t_amplitude = 1.0;");
    w.add("float parameter_t_frequency = 1.0;");
    
    
    #.add("\n");
    
    
    w.add(gwiko.read_string_from_file(str(Path.cwd() ) + "\G_0000.glsl"))

#w.add("void main(){\n")
#w.add("  ivec2 pixel_coords = ivec2(gl_GlobalInvocationID.xy);\n")
#w.add("  vec4 color = vec4(pixel_coords.x / 1920.0, pixel_coords.y / 1080.0, 0.0, 1.0);\n")
#w.add("  color.g = color.g + float(int_frame) * 0.01;\n")
#w.add("  color.r *= 0.74;\n")
#w.add("  imageStore(out0, pixel_coords, color);\n")
#w.add("}\n")




generate_source(w, 100)

v = str(int_type("frame"));
v = str(vec3_type("yojo"));
print(v)
#print(w.get_str())

g = gwiko_generate.Generate("C:/Users/Cosmos/Desktop/output/tmp/")
g.set_size(1920, 1080)

g.generate(w.get_str(), False)
# Out:
# gwiko reloaded successfully.
# gwiko_generate reloaded successfully.
# vec3 yojo = vec3(0.0, 0.0, 0.0);
# Folder 'C:\Users\Cosmos\Desktop\output\tmp' already exists.
# Folder 'C:\Users\Cosmos\Desktop\output\tmp\output' already exists.
# Folder 'C:\Users\Cosmos\Desktop\output\tmp\input' already exists.
# JSON data saved to: C:\Users\Cosmos\Desktop\output\tmp\input/program.json
# File C:\Users\Cosmos\Desktop\output\tmp\output\out_0.png deleted successfully.
# File C:\Users\Cosmos\Desktop\output\tmp\output\generated_shader.glsl.png does not exist.
# File C:\Users\Cosmos\Desktop\output\tmp\output\log.txt deleted successfully.
# Image loaded successfully.
# <PIL.Image.Image image mode=RGB size=1920x1080>
