# %%
import numpy as np
from PIL import Image
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %% [markdown]
# #### How to install wordcloud ?
# pip install wordcloud

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from PIL import Image, ImageOps

# Manually specified list of words with their frequencies

output_folder  = "C:/Users/Cosmos/Desktop/output/v_21_05_2024_01_02/"


word_frequencies = {
    'False': 100,
    'def': 80,
    'if': 90,
    'raise': 70,
    'CIFAR-10': 60,
    'transferring from one modality to another': 60,
    'extract features across tokens': 50,
    'zeroshot generalization': 55,
    'data-rich modality': 45,
    'bitstrings': 40,
    'parse mathematical expressions': 35,
    'linear probing': 30,
    'ListOps': 30,
    'frozen attention layers': 25,
    'linear regression': 20,
    'finetuning layernorm': 20,
}




# Define a function to generate a color for each word
def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    import random
    return "hsl({}, 100%, 50%)".format(random.randint(0, 255))
# Create a word cloud object
wordcloud = WordCloud(
    width=1024,
    height=1024,
    background_color='black',  # Black background
    color_func=color_func
).generate_from_frequencies(word_frequencies)

# Convert to image and add a border
image = wordcloud.to_image()
bordered_image = ImageOps.expand(image, border=5, fill='yellow')

bordered_image.save(output_folder+"generate_image.png")


bordered_image
# Out:
# <PIL.Image.Image image mode=RGB size=1034x1034>

# %%
word_frequencies = {
    'False': 100,
    'def': 80,
    'if': 90,
    'raise': 70,
    'CIFAR-10': 60,
    'transferring from one modality to another': 60,
    'extract features across tokens': 50,
    'zeroshot generalization': 55,
    'data-rich modality': 45,
    'bitstrings': 40,
    'parse mathematical expressions': 35,
    'linear probing': 30,
    'ListOps': 30,
    'frozen attention layers': 25,
    'linear regression': 20,
    'finetuning layernorm': 20,
}

# TODO we could model this as some kind of function that takes in 
# the description and than generates instruction for some state machine 
# this way everting can be more modular by feeding the output as into to another state machine and so on

def generate_data_for_frame(wf, num):
    counter = 0
    output_wf = {}
    for i in wf:
        #print(i)
        #print(wf[i])
        key = ""
        for j in i:
            key += j
            print(key)
            counter += 1
            if(counter == num) :
                output_wf[key] = wf[i]
                return output_wf
        output_wf[key] = wf[i]
    return output_wf
generate_data_for_frame(word_frequencies, 10)
# Out:
# F
# Fa
# Fal
# Fals
# False
# d
# de
# def
# i
# if
# {'False': 100, 'def': 80, 'if': 90}

# %%
word_frequencies = {
    'False': 100,
    'def': 80,
    'if': 90,
    'raise': 70,
    'CIFAR-10': 60,
    'transferring from one modality to another': 60,
    'extract features across tokens': 50,
    'zeroshot generalization': 55,
    'data-rich modality': 45,
    'bitstrings': 40,
    'parse mathematical expressions': 35,
    'linear probing': 30,
    'ListOps': 30,
    'frozen attention layers': 25,
    'linear regression': 20,
    'finetuning layernorm': 20,
}

def generate_data_for_frame(wf, num):
    counter = 0
    output_wf = {}
    for i in wf:
        #print(i)
        #print(wf[i])
        key = ""
        for j in i:
            key += j
            counter += 1
            if(counter == num) :
                output_wf[key] = wf[i]
                return (output_wf, counter)
        output_wf[key] = wf[i]
    return (output_wf, counter)

wf, counter = generate_data_for_frame(word_frequencies, 7)

print(wf)
# Out:
# {'False': 100, 'de': 80}

# %%
word_frequencies = {
    'False': 100,
    'def': 80,
    'if': 90,
    'raise': 70,
    'CIFAR-10': 60,
    'transferring from one modality to another': 60,
    'extract features across tokens': 50,
    'zeroshot generalization': 55,
    'data-rich modality': 45,
    'bitstrings': 40,
    'parse mathematical expressions': 35,
    'linear probing': 30,
    'ListOps': 30,
    'frozen attention layers': 25,
    'linear regression': 20,
    'finetuning layernorm': 20,
}

def generate_data_for_frame(wf, num):
    counter = 0
    output_wf = {}
    for i in wf:
        #print(i)
        #print(wf[i])
        key = ""
        for j in i:
            key += j
            counter += 1
            if(counter == num) :
                output_wf[key] = wf[i]
                return (output_wf, counter)
        output_wf[key] = wf[i]
    return (output_wf, counter)


num = 1

while True:
    wf, counter = generate_data_for_frame(word_frequencies, num)
    
    if(num > counter):
        break
    num += 1
    
    print(wf)
    frame = counter - 1
    print(frame)
# Out:
# {'F': 100}
# 0
# {'Fa': 100}
# 1
# {'Fal': 100}
# 2
# {'Fals': 100}
# 3
# {'False': 100}
# 4
# {'False': 100, 'd': 80}
# 5
# {'False': 100, 'de': 80}
# 6
# {'False': 100, 'def': 80}
# 7
# {'False': 100, 'def': 80, 'i': 90}
# 8
# {'False': 100, 'def': 80, 'if': 90}
# 9
# {'False': 100, 'def': 80, 'if': 90, 'r': 70}
# 10
# {'False': 100, 'def': 80, 'if': 90, 'ra': 70}
# 11
# {'False': 100, 'def': 80, 'if': 90, 'rai': 70}
# 12
# {'False': 100, 'def': 80, 'if': 90, 'rais': 70}
# 13
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70}
# 14
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'C': 60}
# 15
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CI': 60}
# 16
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIF': 60}
# 17
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFA': 60}
# 18
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR': 60}
# 19
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-': 60}
# 20
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-1': 60}
# 21
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60}
# 22
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 't': 60}
# 23
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'tr': 60}
# 24
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'tra': 60}
# 25
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'tran': 60}
# 26
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'trans': 60}
# 27
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transf': 60}
# 28
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transfe': 60}
# 29
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transfer': 60}
# 30
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferr': 60}
# 31
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferri': 60}
# 32
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferrin': 60}
# 33
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring': 60}
# 34
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring ': 60}
# 35
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring f': 60}
# 36
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring fr': 60}
# 37
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring fro': 60}
# 38
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from': 60}
# 39
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from ': 60}
# 40
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from o': 60}
# 41
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from on': 60}
# 42
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one': 60}
# 43
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one ': 60}
# 44
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one m': 60}
# 45
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one mo': 60}
# 46
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one mod': 60}
# 47
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one moda': 60}
# 48
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modal': 60}
# 49
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modali': 60}
# 50
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modalit': 60}
# 51
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality': 60}
# 52
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality ': 60}
# 53
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality t': 60}
# 54
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to': 60}
# 55
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to ': 60}
# 56
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to a': 60}
# 57
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to an': 60}
# 58
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to ano': 60}
# 59
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to anot': 60}
# 60
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to anoth': 60}
# 61
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to anothe': 60}
# 62
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60}
# 63
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'e': 50}
# 64
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'ex': 50}
# 65
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'ext': 50}
# 66
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extr': 50}
# 67
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extra': 50}
# 68
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extrac': 50}
# 69
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract': 50}
# 70
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract ': 50}
# 71
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract f': 50}
# 72
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract fe': 50}
# 73
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract fea': 50}
# 74
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract feat': 50}
# 75
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract featu': 50}
# 76
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract featur': 50}
# 77
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract feature': 50}
# 78
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features': 50}
# 79
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features ': 50}
# 80
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features a': 50}
# 81
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features ac': 50}
# 82
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features acr': 50}
# 83
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features acro': 50}
# 84
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features acros': 50}
# 85
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across': 50}
# 86
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across ': 50}
# 87
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across t': 50}
# 88
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across to': 50}
# 89
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tok': 50}
# 90
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across toke': 50}
# 91
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across token': 50}
# 92
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50}
# 93
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'z': 55}
# 94
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'ze': 55}
# 95
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zer': 55}
# 96
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zero': 55}
# 97
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeros': 55}
# 98
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zerosh': 55}
# 99
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zerosho': 55}
# 100
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot': 55}
# 101
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot ': 55}
# 102
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot g': 55}
# 103
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot ge': 55}
# 104
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot gen': 55}
# 105
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot gene': 55}
# 106
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot gener': 55}
# 107
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot genera': 55}
# 108
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot general': 55}
# 109
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generali': 55}
# 110
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generaliz': 55}
# 111
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generaliza': 55}
# 112
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalizat': 55}
# 113
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalizati': 55}
# 114
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalizatio': 55}
# 115
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55}
# 116
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'd': 45}
# 117
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'da': 45}
# 118
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'dat': 45}
# 119
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data': 45}
# 120
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-': 45}
# 121
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-r': 45}
# 122
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-ri': 45}
# 123
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-ric': 45}
# 124
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich': 45}
# 125
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich ': 45}
# 126
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich m': 45}
# 127
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich mo': 45}
# 128
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich mod': 45}
# 129
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich moda': 45}
# 130
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modal': 45}
# 131
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modali': 45}
# 132
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modalit': 45}
# 133
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45}
# 134
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'b': 40}
# 135
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bi': 40}
# 136
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bit': 40}
# 137
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bits': 40}
# 138
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitst': 40}
# 139
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstr': 40}
# 140
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstri': 40}
# 141
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrin': 40}
# 142
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstring': 40}
# 143
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40}
# 144
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'p': 35}
# 145
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'pa': 35}
# 146
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'par': 35}
# 147
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'pars': 35}
# 148
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse': 35}
# 149
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse ': 35}
# 150
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse m': 35}
# 151
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse ma': 35}
# 152
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mat': 35}
# 153
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse math': 35}
# 154
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathe': 35}
# 155
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathem': 35}
# 156
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathema': 35}
# 157
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathemat': 35}
# 158
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathemati': 35}
# 159
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematic': 35}
# 160
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematica': 35}
# 161
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical': 35}
# 162
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical ': 35}
# 163
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical e': 35}
# 164
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical ex': 35}
# 165
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical exp': 35}
# 166
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expr': 35}
# 167
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expre': 35}
# 168
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expres': 35}
# 169
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical express': 35}
# 170
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressi': 35}
# 171
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressio': 35}
# 172
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expression': 35}
# 173
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35}
# 174
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'l': 30}
# 175
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'li': 30}
# 176
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'lin': 30}
# 177
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'line': 30}
# 178
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linea': 30}
# 179
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear': 30}
# 180
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear ': 30}
# 181
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear p': 30}
# 182
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear pr': 30}
# 183
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear pro': 30}
# 184
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear prob': 30}
# 185
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probi': 30}
# 186
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probin': 30}
# 187
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30}
# 188
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'L': 30}
# 189
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'Li': 30}
# 190
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'Lis': 30}
# 191
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'List': 30}
# 192
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListO': 30}
# 193
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOp': 30}
# 194
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30}
# 195
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'f': 25}
# 196
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'fr': 25}
# 197
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'fro': 25}
# 198
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'froz': 25}
# 199
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'froze': 25}
# 200
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen': 25}
# 201
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen ': 25}
# 202
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen a': 25}
# 203
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen at': 25}
# 204
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen att': 25}
# 205
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen atte': 25}
# 206
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen atten': 25}
# 207
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attent': 25}
# 208
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attenti': 25}
# 209
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attentio': 25}
# 210
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention': 25}
# 211
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention ': 25}
# 212
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention l': 25}
# 213
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention la': 25}
# 214
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention lay': 25}
# 215
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention laye': 25}
# 216
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layer': 25}
# 217
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25}
# 218
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'l': 20}
# 219
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'li': 20}
# 220
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'lin': 20}
# 221
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'line': 20}
# 222
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linea': 20}
# 223
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear': 20}
# 224
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear ': 20}
# 225
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear r': 20}
# 226
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear re': 20}
# 227
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear reg': 20}
# 228
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regr': 20}
# 229
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regre': 20}
# 230
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regres': 20}
# 231
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regress': 20}
# 232
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regressi': 20}
# 233
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regressio': 20}
# 234
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20}
# 235
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'f': 20}
# 236
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'fi': 20}
# 237
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'fin': 20}
# 238
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'fine': 20}
# 239
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finet': 20}
# 240
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetu': 20}
# 241
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetun': 20}
# 242
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuni': 20}
# 243
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetunin': 20}
# 244
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning': 20}
# 245
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning ': 20}
# 246
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning l': 20}
# 247
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning la': 20}
# 248
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning lay': 20}
# 249
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning laye': 20}
# 250
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning layer': 20}
# 251
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning layern': 20}
# 252
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning layerno': 20}
# 253
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning layernor': 20}
# 254
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning layernorm': 20}
# 255

# %%
word_frequencies = {
    'False': 100,
    'def': 80,
    'if': 90,
    'raise': 70,
    'CIFAR-10': 60,
    'transferring from one modality to another': 60,
    'extract features across tokens': 50,
    'zeroshot generalization': 55,
    'data-rich modality': 45,
    'bitstrings': 40,
    'parse mathematical expressions': 35,
    'linear probing': 30,
    'ListOps': 30,
    'frozen attention layers': 25,
    'linear regression': 20,
    'finetuning layernorm': 20,
}

def generate_data_for_frame(wf, num):
    counter = 0
    output_wf = {}
    for i in wf:
        #print(i)
        #print(wf[i])
        key = ""
        for j in i:
            key += j
            counter += 1
            if(counter == num) :
                output_wf[key] = wf[i]
                return (output_wf, counter)
        output_wf[key] = wf[i]
    return (output_wf, counter)


# Define a function to generate a color for each word
def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    import random
    return "hsl({}, 100%, 50%)".format(random.randint(0, 255))







num = 1

while True:
    wf, counter = generate_data_for_frame(word_frequencies, num)
    
    if(num > counter):
        break
    num += 1
    
    print(wf)
    frame = counter - 1
    print(frame)

    # Create a word cloud object
    wordcloud = WordCloud(
        width=1024,
        height=1024,
        background_color='black',  # Black background
        color_func=color_func
    ).generate_from_frequencies(wf)
    # Convert to image and add a border
    image = wordcloud.to_image()
    bordered_image = ImageOps.expand(image, border=5, fill='yellow')
    bordered_image.save(output_folder+"generate_image_"+str(frame)+".png")
# Out:
# {'F': 100}
# 0
# {'Fa': 100}
# 1
# {'Fal': 100}
# 2
# {'Fals': 100}
# 3
# {'False': 100}
# 4
# {'False': 100, 'd': 80}
# 5
# {'False': 100, 'de': 80}
# 6
# {'False': 100, 'def': 80}
# 7
# {'False': 100, 'def': 80, 'i': 90}
# 8
# {'False': 100, 'def': 80, 'if': 90}
# 9
# {'False': 100, 'def': 80, 'if': 90, 'r': 70}
# 10
# {'False': 100, 'def': 80, 'if': 90, 'ra': 70}
# 11
# {'False': 100, 'def': 80, 'if': 90, 'rai': 70}
# 12
# {'False': 100, 'def': 80, 'if': 90, 'rais': 70}
# 13
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70}
# 14
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'C': 60}
# 15
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CI': 60}
# 16
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIF': 60}
# 17
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFA': 60}
# 18
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR': 60}
# 19
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-': 60}
# 20
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-1': 60}
# 21
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60}
# 22
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 't': 60}
# 23
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'tr': 60}
# 24
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'tra': 60}
# 25
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'tran': 60}
# 26
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'trans': 60}
# 27
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transf': 60}
# 28
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transfe': 60}
# 29
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transfer': 60}
# 30
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferr': 60}
# 31
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferri': 60}
# 32
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferrin': 60}
# 33
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring': 60}
# 34
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring ': 60}
# 35
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring f': 60}
# 36
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring fr': 60}
# 37
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring fro': 60}
# 38
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from': 60}
# 39
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from ': 60}
# 40
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from o': 60}
# 41
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from on': 60}
# 42
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one': 60}
# 43
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one ': 60}
# 44
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one m': 60}
# 45
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one mo': 60}
# 46
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one mod': 60}
# 47
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one moda': 60}
# 48
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modal': 60}
# 49
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modali': 60}
# 50
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modalit': 60}
# 51
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality': 60}
# 52
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality ': 60}
# 53
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality t': 60}
# 54
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to': 60}
# 55
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to ': 60}
# 56
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to a': 60}
# 57
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to an': 60}
# 58
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to ano': 60}
# 59
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to anot': 60}
# 60
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to anoth': 60}
# 61
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to anothe': 60}
# 62
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60}
# 63
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'e': 50}
# 64
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'ex': 50}
# 65
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'ext': 50}
# 66
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extr': 50}
# 67
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extra': 50}
# 68
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extrac': 50}
# 69
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract': 50}
# 70
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract ': 50}
# 71
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract f': 50}
# 72
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract fe': 50}
# 73
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract fea': 50}
# 74
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract feat': 50}
# 75
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract featu': 50}
# 76
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract featur': 50}
# 77
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract feature': 50}
# 78
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features': 50}
# 79
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features ': 50}
# 80
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features a': 50}
# 81
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features ac': 50}
# 82
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features acr': 50}
# 83
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features acro': 50}
# 84
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features acros': 50}
# 85
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across': 50}
# 86
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across ': 50}
# 87
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across t': 50}
# 88
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across to': 50}
# 89
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tok': 50}
# 90
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across toke': 50}
# 91
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across token': 50}
# 92
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50}
# 93
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'z': 55}
# 94
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'ze': 55}
# 95
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zer': 55}
# 96
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zero': 55}
# 97
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeros': 55}
# 98
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zerosh': 55}
# 99
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zerosho': 55}
# 100
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot': 55}
# 101
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot ': 55}
# 102
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot g': 55}
# 103
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot ge': 55}
# 104
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot gen': 55}
# 105
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot gene': 55}
# 106
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot gener': 55}
# 107
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot genera': 55}
# 108
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot general': 55}
# 109
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generali': 55}
# 110
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generaliz': 55}
# 111
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generaliza': 55}
# 112
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalizat': 55}
# 113
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalizati': 55}
# 114
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalizatio': 55}
# 115
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55}
# 116
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'd': 45}
# 117
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'da': 45}
# 118
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'dat': 45}
# 119
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data': 45}
# 120
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-': 45}
# 121
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-r': 45}
# 122
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-ri': 45}
# 123
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-ric': 45}
# 124
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich': 45}
# 125
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich ': 45}
# 126
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich m': 45}
# 127
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich mo': 45}
# 128
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich mod': 45}
# 129
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich moda': 45}
# 130
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modal': 45}
# 131
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modali': 45}
# 132
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modalit': 45}
# 133
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45}
# 134
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'b': 40}
# 135
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bi': 40}
# 136
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bit': 40}
# 137
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bits': 40}
# 138
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitst': 40}
# 139
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstr': 40}
# 140
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstri': 40}
# 141
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrin': 40}
# 142
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstring': 40}
# 143
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40}
# 144
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'p': 35}
# 145
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'pa': 35}
# 146
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'par': 35}
# 147
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'pars': 35}
# 148
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse': 35}
# 149
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse ': 35}
# 150
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse m': 35}
# 151
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse ma': 35}
# 152
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mat': 35}
# 153
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse math': 35}
# 154
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathe': 35}
# 155
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathem': 35}
# 156
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathema': 35}
# 157
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathemat': 35}
# 158
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathemati': 35}
# 159
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematic': 35}
# 160
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematica': 35}
# 161
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical': 35}
# 162
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical ': 35}
# 163
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical e': 35}
# 164
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical ex': 35}
# 165
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical exp': 35}
# 166
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expr': 35}
# 167
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expre': 35}
# 168
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expres': 35}
# 169
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical express': 35}
# 170
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressi': 35}
# 171
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressio': 35}
# 172
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expression': 35}
# 173
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35}
# 174
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'l': 30}
# 175
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'li': 30}
# 176
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'lin': 30}
# 177
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'line': 30}
# 178
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linea': 30}
# 179
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear': 30}
# 180
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear ': 30}
# 181
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear p': 30}
# 182
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear pr': 30}
# 183
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear pro': 30}
# 184
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear prob': 30}
# 185
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probi': 30}
# 186
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probin': 30}
# 187
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30}
# 188
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'L': 30}
# 189
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'Li': 30}
# 190
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'Lis': 30}
# 191
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'List': 30}
# 192
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListO': 30}
# 193
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOp': 30}
# 194
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30}
# 195
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'f': 25}
# 196
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'fr': 25}
# 197
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'fro': 25}
# 198
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'froz': 25}
# 199
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'froze': 25}
# 200
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen': 25}
# 201
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen ': 25}
# 202
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen a': 25}
# 203
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen at': 25}
# 204
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen att': 25}
# 205
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen atte': 25}
# 206
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen atten': 25}
# 207
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attent': 25}
# 208
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attenti': 25}
# 209
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attentio': 25}
# 210
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention': 25}
# 211
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention ': 25}
# 212
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention l': 25}
# 213
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention la': 25}
# 214
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention lay': 25}
# 215
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention laye': 25}
# 216
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layer': 25}
# 217
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25}
# 218
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'l': 20}
# 219
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'li': 20}
# 220
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'lin': 20}
# 221
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'line': 20}
# 222
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linea': 20}
# 223
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear': 20}
# 224
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear ': 20}
# 225
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear r': 20}
# 226
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear re': 20}
# 227
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear reg': 20}
# 228
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regr': 20}
# 229
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regre': 20}
# 230
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regres': 20}
# 231
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regress': 20}
# 232
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regressi': 20}
# 233
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regressio': 20}
# 234
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20}
# 235
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'f': 20}
# 236
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'fi': 20}
# 237
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'fin': 20}
# 238
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'fine': 20}
# 239
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finet': 20}
# 240
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetu': 20}
# 241
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetun': 20}
# 242
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuni': 20}
# 243
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetunin': 20}
# 244
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning': 20}
# 245
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning ': 20}
# 246
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning l': 20}
# 247
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning la': 20}
# 248
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning lay': 20}
# 249
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning laye': 20}
# 250
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning layer': 20}
# 251
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning layern': 20}
# 252
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning layerno': 20}
# 253
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning layernor': 20}
# 254
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot generalization': 55, 'data-rich modality': 45, 'bitstrings': 40, 'parse mathematical expressions': 35, 'linear probing': 30, 'ListOps': 30, 'frozen attention layers': 25, 'linear regression': 20, 'finetuning layernorm': 20}
# 255

# %%
word_frequencies = {
    'False': 100,
    'def': 80,
    'if': 90,
    'raise': 70,
    'CIFAR-10': 60,
    'transferring from one modality to another': 60,
    'extract features across tokens': 50,
    'zeroshot generalization': 55,
    'data-rich modality': 45,
    'bitstrings': 40,
    'parse mathematical expressions': 35,
    'linear probing': 30,
    'ListOps': 30,
    'frozen attention layers': 25,
    'linear regression': 20,
    'finetuning layernorm': 20,
}


def generate(word_frequencies_data, width, height):
    def generate_data_for_frame(wf, num):
        counter = 0
        output_wf = {}
        for i in wf:
            #print(i)
            #print(wf[i])
            key = ""
            for j in i:
                key += j
                counter += 1
                if(counter == num) :
                    output_wf[key] = wf[i]
                    return (output_wf, counter)
            output_wf[key] = wf[i]
        return (output_wf, counter)

    # Define a function to generate a color for each word
    def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
        import random
        return "hsl({}, 100%, 50%)".format(random.randint(0, 255))
    
    num = 1

    while True:
        wf, counter = generate_data_for_frame(word_frequencies_data, num)
    
        if(num > counter):
            break
        num += 1
    
        print(wf)
        frame = counter - 1
        print(frame)

        # Create a word cloud object
        wordcloud = WordCloud(
            width=width,
            height=height,
            background_color='black',  # Black background
            color_func=color_func
        ).generate_from_frequencies(wf)
        # Convert to image and add a border
        image = wordcloud.to_image()
        bordered_image = ImageOps.expand(image, border=5, fill='yellow')
        bordered_image.save(output_folder+"generate_image_"+str(frame)+".png")


generate(word_frequencies, 1920, 1080)
# Out:
# {'F': 100}
# 0
# {'Fa': 100}
# 1
# {'Fal': 100}
# 2
# {'Fals': 100}
# 3
# {'False': 100}
# 4
# {'False': 100, 'd': 80}
# 5
# {'False': 100, 'de': 80}
# 6
# {'False': 100, 'def': 80}
# 7
# {'False': 100, 'def': 80, 'i': 90}
# 8
# {'False': 100, 'def': 80, 'if': 90}
# 9
# {'False': 100, 'def': 80, 'if': 90, 'r': 70}
# 10
# {'False': 100, 'def': 80, 'if': 90, 'ra': 70}
# 11
# {'False': 100, 'def': 80, 'if': 90, 'rai': 70}
# 12
# {'False': 100, 'def': 80, 'if': 90, 'rais': 70}
# 13
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70}
# 14
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'C': 60}
# 15
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CI': 60}
# 16
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIF': 60}
# 17
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFA': 60}
# 18
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR': 60}
# 19
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-': 60}
# 20
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-1': 60}
# 21
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60}
# 22
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 't': 60}
# 23
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'tr': 60}
# 24
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'tra': 60}
# 25
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'tran': 60}
# 26
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'trans': 60}
# 27
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transf': 60}
# 28
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transfe': 60}
# 29
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transfer': 60}
# 30
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferr': 60}
# 31
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferri': 60}
# 32
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferrin': 60}
# 33
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring': 60}
# 34
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring ': 60}
# 35
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring f': 60}
# 36
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring fr': 60}
# 37
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring fro': 60}
# 38
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from': 60}
# 39
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from ': 60}
# 40
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from o': 60}
# 41
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from on': 60}
# 42
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one': 60}
# 43
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one ': 60}
# 44
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one m': 60}
# 45
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one mo': 60}
# 46
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one mod': 60}
# 47
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one moda': 60}
# 48
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modal': 60}
# 49
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modali': 60}
# 50
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modalit': 60}
# 51
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality': 60}
# 52
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality ': 60}
# 53
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality t': 60}
# 54
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to': 60}
# 55
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to ': 60}
# 56
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to a': 60}
# 57
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to an': 60}
# 58
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to ano': 60}
# 59
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to anot': 60}
# 60
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to anoth': 60}
# 61
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to anothe': 60}
# 62
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60}
# 63
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'e': 50}
# 64
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'ex': 50}
# 65
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'ext': 50}
# 66
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extr': 50}
# 67
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extra': 50}
# 68
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extrac': 50}
# 69
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract': 50}
# 70
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract ': 50}
# 71
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract f': 50}
# 72
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract fe': 50}
# 73
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract fea': 50}
# 74
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract feat': 50}
# 75
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract featu': 50}
# 76
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract featur': 50}
# 77
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract feature': 50}
# 78
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features': 50}
# 79
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features ': 50}
# 80
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features a': 50}
# 81
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features ac': 50}
# 82
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features acr': 50}
# 83
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features acro': 50}
# 84
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features acros': 50}
# 85
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across': 50}
# 86
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across ': 50}
# 87
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across t': 50}
# 88
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across to': 50}
# 89
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tok': 50}
# 90
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across toke': 50}
# 91
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across token': 50}
# 92
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50}
# 93
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'z': 55}
# 94
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'ze': 55}
# 95
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zer': 55}
# 96
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zero': 55}
# 97
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeros': 55}
# 98
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zerosh': 55}
# 99
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zerosho': 55}
# 100
# {'False': 100, 'def': 80, 'if': 90, 'raise': 70, 'CIFAR-10': 60, 'transferring from one modality to another': 60, 'extract features across tokens': 50, 'zeroshot': 55}
# 101
