# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from PIL import Image, ImageOps

# Manually specified list of words with their frequencies

			


word_frequencies = {
    'False': 100,
    'def': 80,
    'if': 90,
    'raise': 70,
    'CIFAR-10': 60,
    'transferring from one modality to another': 60,
    'extract features across tokens': 50,
    'zeroshot generalization': 55,
    'data-rich modality': 45,
    'bitstrings': 40,
    'parse mathematical expressions': 35,
    'linear probing': 30,
    'ListOps': 30,
    'frozen attention layers': 25,
    'linear regression': 20,
    'finetuning layernorm': 20,
}

# Define a function to generate a color for each word
def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    import random
    return "hsl({}, 100%, 50%)".format(random.randint(0, 255))

# Create a word cloud object
wordcloud = WordCloud(
    width=1024,
    height=1024,
    background_color='black',  # Black background
    color_func=color_func
).generate_from_frequencies(word_frequencies)

# Convert to image and add a border
image = wordcloud.to_image()
bordered_image = ImageOps.expand(image, border=5, fill='yellow')

bordered_image.save("generate_image.png")


bordered_image
# Out:
# <PIL.Image.Image image mode=RGB size=1034x1034>

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from PIL import Image, ImageOps

# Manually specified list of words with their frequencies
word_frequencies = {
    "C++": 100,
    "Templates": 90,
    "STL": 85,
    "Object-Oriented": 80,
    "Polymorphism": 75,
    "Inheritance": 70,
    "Encapsulation": 65,
    "RAII": 60,
    "Smart Pointers": 55,
    "Lambdas": 50,
    "Multithreading": 45,
    "Move Semantics": 40,
    "constexpr": 35,
    "auto": 30,
    "Namespaces": 25,
    "Virtual Functions": 20,
    "Exceptions": 20,
    "Standard Library": 90,
    "Containers": 85,
    "Algorithms": 80,
    "Iterators": 75,
    "Streams": 70,
    "Strings": 65,
    "IOStreams": 60,
    "File Handling": 55,
    "Concurrency": 50,
    "Atomic Operations": 45,
    "Regular Expressions": 40,
    "Time Utilities": 35,
    "Networking": 30,
    "Sockets": 25,
    "HTTP": 20,
    "Graphics": 20,
    "OpenGL": 15,
    "DirectX": 10,
    "Parallel Programming": 90,
    "OpenMP": 85,
    "MPI": 80,
    "CUDA": 75,
    "Threading Building Blocks": 70,
    "Asynchronous IO": 65,
    "Coroutine": 60,
    "Task-Based Parallelism": 55,
    "Futures": 50,
    "Async/Await": 45,
    "Error Handling": 40,
    "Error Codes": 35,
    "Assertions": 30,
    "Logging": 25,
    "Debugging": 20,
    "Performance Optimization": 90,
    "Profiling": 85,
    "Compiler Optimization": 80,
    "Cache Optimization": 75,
    "Vectorization": 70,
    "Inline Functions": 65,
    "Loop Unrolling": 60,
    "Memory Management": 55,
    "Dynamic Memory Allocation": 50,
    "Memory Pools": 45,
    "Memory Leaks Detection": 40,
    "Garbage Collection": 35,
    "Memory Safety": 30,
    "Security Features": 25,
    "Sandboxing": 20,
    "Concurrency Control": 90,
    "Locks": 85,
    "Mutexes": 80,
    "Condition Variables": 75,
    "Semaphores": 70,
    "Atomic Operations": 65,
    "Read-Write Locks": 60,
    "Thread Safety": 55,
    "Transactional Memory": 50,
    "Data Structures": 90,
    "Arrays": 85,
    "Vectors": 80,
    "Lists": 75,
    "Stacks": 70,
    "Queues": 65,
    "Sets": 60,
    "Maps": 55,
    "Hash Tables": 50,
    "Trees": 45,
    "Graphs": 40,
    "Trie": 35,
    "Heap": 30,
    "Bloom Filter": 25,
    "Skip List": 20,
    "Design Patterns": 90,
    "Creational Patterns": 85,
    "Singleton": 80,
    "Factory": 75,
    "Abstract Factory": 70,
    "Builder": 65,
    "Prototype": 60,
    "Structural Patterns": 55,
    "Adapter": 50,
    "Bridge": 45,
    "Composite": 40,
    "Decorator": 35,
    "Facade": 30,
    "Flyweight": 25,
    "Proxy": 20,
    "Behavioral Patterns": 90,
    "Observer": 85,
    "Strategy": 80,
    "Command": 75,
    "State": 70,
    "Visitor": 65,
    "Iterator": 60,
    "Mediator": 55,
    "Memento": 50,
    "Template Method": 45,
    "Chain of Responsibility": 40,
    "Interpreter": 35,
    "Null Object": 30,
    "Concurrency Patterns": 90,
    "Active Object": 85,
    "Monitor Object": 80,
    "Thread-Specific Storage": 75,
    "Thread Pool": 70,
    "Thread-Local Storage": 65,
    "Guarded Suspension": 60,
    "Double-Checked Locking": 55,
    "Thread-Local Singleton": 50,
    "Immutable Object": 45,
    "Thread-Safe Interface": 40,
    "Thread-Safe Wrapper": 35,
    "Immutable Data Structures": 30,
    "Lock-Free Data Structures": 25,
    "Wait-Free Data Structures": 20
}
# Define a function to generate a color for each word
def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    import random
    return "hsl({}, 100%, 50%)".format(random.randint(0, 255))

# Create a word cloud object
wordcloud = WordCloud(
    width=1024,
    height=1024,
    background_color='black',  # Black background
    color_func=color_func
).generate_from_frequencies(word_frequencies)

# Convert to image and add a border
image = wordcloud.to_image()
bordered_image = ImageOps.expand(image, border=5, fill='yellow')

bordered_image.save("generate_image.png")


bordered_image
# Out:
# <PIL.Image.Image image mode=RGB size=1034x1034>
